# %% [markdown]
# <a href="https://colab.research.google.com/github/sreeniedp/Data-Science-Projects/blob/master/MFL_Daywise_sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
MFL= pd.read_csv('MFL_data_sorted.csv',index_col=False)

# %%
MFL=MFL[['Ct_Date','Day','Ct_Time','GLPLNOS']]

# %%
MFL.head()
# Out:
#       Ct_Date     Day  Ct_Time  GLPLNOS
# 0  2017-12-11  Monday       10     91.0
# 1  2017-12-11  Monday       12   1117.0
# 2  2017-12-11  Monday       14   2708.0
# 3  2017-12-11  Monday       16   3761.0
# 4  2017-12-11  Monday       18   4591.0

# %%
MFL.Ct_Time.unique()
# Out:
# array([10, 12, 14, 16, 18, 20, 22])

# %%
MFL.Day.unique()
# Out:
# array(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'],
#       dtype=object)

# %%
MFL.Ct_Date.unique()
# Out:
# array(['2017-12-11', '2017-12-12', '2017-12-13', '2017-12-14',
#        '2017-12-15', '2017-12-16', '2017-12-18', '2017-12-19',
#        '2017-12-20', '2017-12-21', '2017-12-22', '2017-12-23',
#        '2017-12-25', '2017-12-26', '2017-12-27', '2017-12-28',
#        '2017-12-29', '2017-12-30', '2018-01-01', '2018-01-02',
#        '2018-01-03', '2018-01-04', '2018-01-05', '2018-01-06',
#        '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#        '2018-01-12', '2018-01-13', '2018-01-15', '2018-01-16',
#        '2018-01-17', '2018-01-18', '2018-01-19', '2018-01-20',
#        '2018-01-22', '2018-01-23', '2018-01-24', '2018-01-25',
#        '2018-01-26', '2018-01-27', '2018-01-29', '2018-01-30',
#        '2018-01-31', '2018-02-01', '2018-02-02', '2018-02-03',
#        '2018-02-05', '2018-02-06', '2018-02-07', '2018-02-08',
#        '2018-02-09', '2018-02-10', '2018-02-12', '2018-02-13',
#        '2018-02-14', '2018-02-15', '2018-02-16', '2018-02-17',
# ...

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
MFL_grouped_day=MFL.groupby(['Day','Ct_Date','Ct_Time']).agg([sum,min,max])
#grouped.columns = ["_".join(x) for x in grouped.columns.ravel()]

# %%
MFL_grouped_day.columns
# Out:
# MultiIndex([('GLPLNOS', 'sum'),
#             ('GLPLNOS', 'min'),
#             ('GLPLNOS', 'max')],
#            )

# %%
MFL_grouped_day.index
# Out:
# MultiIndex([(   'Friday', '2017-12-15', 10),
#             (   'Friday', '2017-12-15', 12),
#             (   'Friday', '2017-12-15', 14),
#             (   'Friday', '2017-12-15', 16),
#             (   'Friday', '2017-12-15', 18),
#             (   'Friday', '2017-12-15', 20),
#             (   'Friday', '2017-12-22', 10),
#             (   'Friday', '2017-12-22', 12),
#             (   'Friday', '2017-12-22', 14),
#             (   'Friday', '2017-12-22', 16),
#             ...
#             ('Wednesday', '2020-12-23', 18),
#             ('Wednesday', '2020-12-23', 20),
#             ('Wednesday', '2020-12-23', 22),
#             ('Wednesday', '2020-12-30', 10),
#             ('Wednesday', '2020-12-30', 12),
#             ('Wednesday', '2020-12-30', 14),
#             ('Wednesday', '2020-12-30', 16),
#             ('Wednesday', '2020-12-30', 18),
#             ('Wednesday', '2020-12-30', 20),
#             ('Wednesday', '2020-12-30', 22)],
# ...

# %% [markdown]
# array(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'],

# %%
MFL_Mon=MFL_grouped_day.loc['Monday']
MFL_Tue=MFL_grouped_day.loc['Tuesday']
MFL_Wed=MFL_grouped_day.loc['Wednesday']
MFL_Thu=MFL_grouped_day.loc['Thursday']
MFL_Fri=MFL_grouped_day.loc['Friday']
MFL_Sat=MFL_grouped_day.loc['Saturday']

# %%
(len(MFL_Mon),len(MFL_Tue),len(MFL_Wed),len(MFL_Thu),len(MFL_Fri),len(MFL_Sat))
# Out:
# (1040, 1046, 1043, 1041, 1032, 1037)

# %%
MFL_Mon.head()
# Out:
#                     GLPLNOS
#                         sum   min     max
# Ct_Date    Ct_Time
# 2017-12-11 10         754.0   1.0   279.0
#            12        8211.0  23.0  2655.0
#            14       18047.0  44.0  5372.0
#            16       25007.0  49.0  7253.0
#            18       30213.0  60.0  8742.0
