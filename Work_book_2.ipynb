# %% [markdown]
# <a href="https://colab.research.google.com/github/sreeniedp/Data-Science-Projects/blob/master/Work_book_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
MFL_data= pd.read_csv("MFL_data.csv",index_col=False)

# %%
MFL_data.set_index("State",inplace=True)

# %%
MFL_data
# Out:
#                  Fdgl                     Branch     Ct_Date       Day  \
# State
# Tamil Nadu      F2287  OLD WASHERMENPET-T.H ROAD  2017-12-11    Monday
# Tamil Nadu      F2287  OLD WASHERMENPET-T.H ROAD  2017-12-11    Monday
# Tamil Nadu      F2287  OLD WASHERMENPET-T.H ROAD  2017-12-11    Monday
# Tamil Nadu      F2287  OLD WASHERMENPET-T.H ROAD  2017-12-11    Monday
# Tamil Nadu      F2287  OLD WASHERMENPET-T.H ROAD  2017-12-11    Monday
# ...               ...                        ...         ...       ...
# Andhra Pradesh  F4339                  MUDIGUBBA  2020-12-31  Thursday
# Andhra Pradesh  F4339                  MUDIGUBBA  2020-12-31  Thursday
# Andhra Pradesh  F4339                  MUDIGUBBA  2020-12-31  Thursday
# Andhra Pradesh  F4339                  MUDIGUBBA  2020-12-31  Thursday
# Andhra Pradesh  F4339                  MUDIGUBBA  2020-12-31  Thursday
#
#                 Ct_Time  GLPLNOS       City  PinCode
# State
# ...

# %%
MFL_data1=MFL_data.loc[:,('Ct_Date','Day','Ct_Time','GLPLNOS')]

# %%
MFL_data_sorted=MFL_data1.groupby(['State','Ct_Date','Day','Ct_Time']).sum()

# %%
MFL_data_sorted.to_csv("MFL_data_sorted.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-da310c74c354> in <module>()
# ----> 1 MFL_data_sorted.to_csv("MFL_data_sorted.csv")
#
# NameError: name 'MFL_data_sorted' is not defined

# %%
MFL_data_sorted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8a2afcce4f90> in <module>()
# ----> 1 MFL_data_sorted
#
# NameError: name 'MFL_data_sorted' is not defined

# %%
MFL=pd.read_csv("MFL_data_sorted.csv")

# %%
MFL.head(50)
# Out:
#              State     Ct_Date        Day  Ct_Time  GLPLNOS
# 0   Andhra Pradesh  2017-12-11     Monday       10     91.0
# 1   Andhra Pradesh  2017-12-11     Monday       12   1117.0
# 2   Andhra Pradesh  2017-12-11     Monday       14   2708.0
# 3   Andhra Pradesh  2017-12-11     Monday       16   3761.0
# 4   Andhra Pradesh  2017-12-11     Monday       18   4591.0
# 5   Andhra Pradesh  2017-12-11     Monday       20   4619.0
# 6   Andhra Pradesh  2017-12-12    Tuesday       10     56.0
# 7   Andhra Pradesh  2017-12-12    Tuesday       12    806.0
# 8   Andhra Pradesh  2017-12-12    Tuesday       14   1690.0
# 9   Andhra Pradesh  2017-12-12    Tuesday       16   2421.0
# 10  Andhra Pradesh  2017-12-12    Tuesday       18   3051.0
# 11  Andhra Pradesh  2017-12-12    Tuesday       20   3074.0
# 12  Andhra Pradesh  2017-12-13  Wednesday       10     57.0
# 13  Andhra Pradesh  2017-12-13  Wednesday       12    998.0
# 14  Andhra Pradesh  2017-12-13  Wednesday       14   2001.0
# ...

# %%
MFL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110378 entries, 0 to 110377
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   State    110378 non-null  object
#  1   Ct_Date  110378 non-null  object
#  2   Day      110378 non-null  object
#  3   Ct_Time  110378 non-null  int64
#  4   GLPLNOS  110378 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 4.2+ MB

# %%
MFL['Ct_Date'] = MFL['Ct_Date'].astype('datetime64[ns]')

# %%
MFL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110378 entries, 0 to 110377
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   State    110378 non-null  object
#  1   Ct_Date  110378 non-null  datetime64[ns]
#  2   Day      110378 non-null  object
#  3   Ct_Time  110378 non-null  int64
#  4   GLPLNOS  110378 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 4.2+ MB

# %%
days=list(MFL.Day.unique())

# %%
days.values
# Out:
# array([['Monday'],
#        ['Tuesday'],
#        ['Wednesday'],
#        ['Thursday'],
#        ['Friday'],
#        ['Saturday']], dtype=object)

# %%
#pd.DataFrame(MFL.Day.unique()).values()

# %%
MFL['Monday']=MFL['Day'].apply(lambda x: 1 if x == 'Monday' else 0)
MFL['Tuesday']=MFL['Day'].apply(lambda x: 1 if x == 'Tuesday' else 0)
MFL['Wednesday']=MFL['Day'].apply(lambda x: 1 if x == 'Wednesday' else 0)
MFL['Thursday']=MFL['Day'].apply(lambda x: 1 if x == 'Thursday' else 0)
MFL['Friday']=MFL['Day'].apply(lambda x: 1 if x == 'Friday' else 0)
MFL['Saturday']=MFL['Day'].apply(lambda x: 1 if x == 'Saturday' else 0)

# %%
#  MFL['Day'].apply(lambda x: 1 if x == pd.DataFrame(MFL.Day.unique()).values.any() else 0)

# %%
MFL
# Out:
#                  State    Ct_Date       Day  ...  Thursday  Friday  Saturday
# 0       Andhra Pradesh 2017-12-11    Monday  ...         0       0         0
# 1       Andhra Pradesh 2017-12-11    Monday  ...         0       0         0
# 2       Andhra Pradesh 2017-12-11    Monday  ...         0       0         0
# 3       Andhra Pradesh 2017-12-11    Monday  ...         0       0         0
# 4       Andhra Pradesh 2017-12-11    Monday  ...         0       0         0
# ...                ...        ...       ...  ...       ...     ...       ...
# 110373     West Bengal 2020-12-31  Thursday  ...         1       0         0
# 110374     West Bengal 2020-12-31  Thursday  ...         1       0         0
# 110375     West Bengal 2020-12-31  Thursday  ...         1       0         0
# 110376     West Bengal 2020-12-31  Thursday  ...         1       0         0
# 110377     West Bengal 2020-12-31  Thursday  ...         1       0         0
#
# [110378 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
MFL[['Ct_Date','Ct_Time','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']]
# Out:
#           Ct_Date  Ct_Time  Monday  ...  Thursday  Friday  Saturday
# 0      2017-12-11       10       1  ...         0       0         0
# 1      2017-12-11       12       1  ...         0       0         0
# 2      2017-12-11       14       1  ...         0       0         0
# 3      2017-12-11       16       1  ...         0       0         0
# 4      2017-12-11       18       1  ...         0       0         0
# ...           ...      ...     ...  ...       ...     ...       ...
# 110373 2020-12-31       14       0  ...         1       0         0
# 110374 2020-12-31       16       0  ...         1       0         0
# 110375 2020-12-31       18       0  ...         1       0         0
# 110376 2020-12-31       20       0  ...         1       0         0
# 110377 2020-12-31       22       0  ...         1       0         0
#
# [110378 rows x 8 columns]

# %%
MFL[['GLPLNOS']]
# Out:
#         GLPLNOS
# 0          91.0
# 1        1117.0
# 2        2708.0
# 3        3761.0
# 4        4591.0
# ...         ...
# 110373    526.0
# 110374    794.0
# 110375    974.0
# 110376    976.0
# 110377    976.0
#
# [110378 rows x 1 columns]

# %%
X=MFL[['Ct_Time','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']]
y=MFL[['GLPLNOS']]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y , random_state=0)

# %%
X_train
# Out:
#        Ct_Time  Monday  Tuesday  Wednesday  Thursday  Friday  Saturday
# 37550       22       0        0          1         0       0         0
# 1110        18       1        0          0         0       0         0
# 43512       18       0        0          1         0       0         0
# 74845       10       0        0          1         0       0         0
# 48307       14       0        1          0         0       0         0
# ...        ...     ...      ...        ...       ...     ...       ...
# 21243       20       0        1          0         0       0         0
# 45891       12       0        0          0         0       1         0
# 42613       14       0        0          1         0       0         0
# 43567       20       0        0          0         0       0         1
# 68268       10       0        0          0         0       0         1
#
# [82783 rows x 7 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82783 entries, 37550 to 68268
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Ct_Time    82783 non-null  int64
#  1   Monday     82783 non-null  int64
#  2   Tuesday    82783 non-null  int64
#  3   Wednesday  82783 non-null  int64
#  4   Thursday   82783 non-null  int64
#  5   Friday     82783 non-null  int64
#  6   Saturday   82783 non-null  int64
# dtypes: int64(7)
# memory usage: 5.1 MB

# %%
from sklearn.linear_model import Ridge
linridge = Ridge(alpha=20.0).fit(X_train, y_train)
